# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

url = "https://www.poetryfoundation.org/poems/browse?page=1"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'lxml')

print(soup.prettify()[:1000])  # Print first 1000 characters of the HTML
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    All Poems | The Poetry Foundation
#   </title>
#   <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <link href="/favicon.ico?v2.0.0" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon-16x16.png?v2.0.0" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicon-32x32.png?v2.0.0" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-96x96.png?v2.0.0" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/favicon-192x192.png?v2.0.0" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/favicon-160x160.png?v2.0.0" rel="icon" sizes="160x160" type="image/png"/>
#   <link href="/favicon-196x196.png?v2.0.0" rel="icon" sizes="196x196" type="image/png"/>
# ...

# %% [markdown]
# -  I wanted to try scrape another poetry website, that had less American-Centric poems, but there was a lot of Javascript on the other websites I found making it too tricky.
#
# - In the end I asked people for their favourite poems through Instagram.
#
# - It was really fun and personal this way- I got to learn more about my friends!
