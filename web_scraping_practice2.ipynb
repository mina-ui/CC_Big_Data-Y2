# %% [markdown]
# ### Tutorial Followed: [Web Scraping Project for Beginners Using Python - Books to Scrape](https://www.youtube.com/watch?v=yoE5pmotmjU)

# %%
from bs4 import BeautifulSoup
import requests
import schedule
import time

# %%
# html_text = requests.get('https://books.toscrape.com/').text
# soup = BeautifulSoup(html_text, 'lxml')
# books = soup.find('li', class_ = 'col-xs-6 col-sm-4 col-md-3 col-lg-3')

# print(books)
# Out:
# <li class="col-xs-6 col-sm-4 col-md-3 col-lg-3">
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>
# </li>

# %%
# book_title = books.find('h3').text

# print(book_title)
# Out:
# A Light in the ...

# %%
# print(f'''
#       Book Title: {book_title}
#       ''')
# Out:
#       Book Title: A Light in the ...

# %%
url = 'https://books.toscrape.com/'

def scrape_books():
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.select('.product_pod')
    for book in books:
        title = book.h3.a['title']
        rating = book.p['class'][1]
        print(f"Title: {title,}, Rating: {rating}")

# %%
schedule.every(10).minutes.do(scrape_books)

print("Scraper started...")

while True:
    schedule.run_pending()
    time.sleep(60)
# Out:
# Scraper started...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 while True:
#       6     schedule.run_pending()
# ----> 7     time.sleep(60)
#
# KeyboardInterrupt:

# %%
import csv 

def scrape_books():
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.select(".product_pod")
    with open("books.csv", "a", newline="") as file:
        writer = csv.writer(file)
        for book in books:
            title = book.h3.a["title"]
            rating = book.p["class"][1]
            writer.writerow([title, rating])
            print(f"Saved: {title} - {rating}")
